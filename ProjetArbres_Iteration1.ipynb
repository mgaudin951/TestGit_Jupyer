# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    for index, row in enumerate(line_reader):
        while index < 2:
            print("".join(row))
            break
# Out:
# ﻿ELEM_POINT_IDCODENOMGENREGENRE_DESCCATEGORIECATEGORIE_DESCSOUS_CATEGORIESOUS_CATEGORIE_DESCCODE_PARENTCODE_PARENT_DESCADR_SECTEURBIEN_REFERENCEGENRE_BOTAESPECEVARIETESTADEDEDEVELOPPEMENTEQUIPEREMARQUESANNEEDEPLANTATIONRAISONDEPLANTATIONTRAITEMENTCHENILLESCOURRIERIDENTIFIANTPLUTYPEIMPLANTATIONPLUINTITULEPROTECTIONPLUANNEEABATTAGEESSOUCHEMENTDIAMETREARBRECAUSEABATTAGECOLLECTIVITEGeoJSON
# 31906ESP32632ESP32632VEGVEGETATIONESP01ArbreESP174Arbre d'espaces ouvertsESP995Prc Echangeurs Bastion St Roch5AR32632AcerpseudoplatanusArbre adulte2001Ville de Grenoble{"type":"Point","coordinates":[5.74072726311972,45.1905385120349]}

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    list_plantation = []
    for row in line_reader:
        list_plantation.append(row[19])
    for row in list_plantation:
        print(row)
# Out:
# ANNEEDEPLANTATION
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 1975
# 1975
# 1975
# 2001
# 2001
# 1975
# 1975
# 1975
# 1975
# 2001
# 1975
# 2001
# 1975
# 2001
# 1975
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 2003
# 2003
# 2003
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1985
# 1975
# 1975
# 1975
# 1975
# 1977
# 1977
# 1977
# 1977
#
#
#
#
#
#
# 2001
# 2001
# 2001
# 2001
# 1975
# 1975
# 1975
# 1975
# 2006
# 1975
# 1975
# 1975
# 1975
# 2001
# 1975
# 1975
# 2001
# 2001
# 1975
# 1975
# 2001
# 1975
# 2001
# 1975
# 1975
# 2001
# 1975
# 2006
# 1975
# 1975
# 1975
# 1975
# 2001
# 2001
# 1975
# 1975
# 2001
# 2001
# 2001
# 1975
# 1975
# 1975
# 1975
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 1975
# 2006
# 1975
# 1975
# 1975
# 2001
# 1975
# 2001
# 2006
# 1975
# 1975
# 1975
# 1975
# 2001
# 2001
# 1975
# 1975
# 1975
# 1975
# ...

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    list_plantation = []
    for row in line_reader:
        list_plantation.append(row[19])
    for i, v in enumerate(list_plantation):
        if i < 50 or i > len(list_plantation)-52:
            print(v)
# Out:
# ANNEEDEPLANTATION
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 1975
# 1975
# 1975
# 2001
# 2001
# 1975
# 1975
# 1975
# 1975
# 2001
# 1975
# 2001
# 1975
# 2001
# 1975
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1969
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 1965
# 2003
# 2003
# 2003
# 1985
# 1985
# 1985
# 1985
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 1967
# 2015
# 1967
# 1967
# 1967
# 1967
# 1967
# 1976
# 1976
# 1976
# 1976
# 1976
# 1976
# 1975
# 1975
# 1975
# 2015
#
#
# 1987
# 1987
# 1996
# 1987
# 1987
# 1987
# 1960
# 1987
# 1987
# 1987
# 1987
# 1987
# 1996
# 1987
# 1987

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    list_plantation = []
    for row in line_reader:
        list_plantation.append(row[19])
    count = list_plantation.count("")
    print(count)
# Out:
# 1392

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    list_tot = []
    i = 0
    for row in line_reader:
        list_tot.append(row)
        i += 1
    print(i)
# Out:
# 31815

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    list_annee = []
    for row in list_plantation:
        if row != "":
            list_annee.append(row)
    an = (int(max(list_annee[1:])) - int(min(list_annee[1:])))
    print(an)
    moyenne = i/an
    print(moyenne)
# Out:
# 68
# 467.86764705882354

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    arbre_born = []
    for row in list_tot:
        if row[19] == "1989":
            arbre_born.append(row)
    print(arbre_born)
# Out:
# [['20839', 'ESP26231', 'ESP26231', 'VEG', 'VEGETATION', 'ESP01', 'Arbre', 'ESP151', 'Arbre de voirie', 'ESP1018', 'R Jacquard Kenedy à Louvois', '4', 'AR26231', 'Sophora', 'japonica', '', 'Arbre adulte', '', 'MODIF', '1989', '', '', '', '', '', '', '', '', '', '', 'Grenoble Alpes Métropole', '{"type":"Point","coordinates":[5.71942829088963,45.1755465516565]}'], ['13522', 'ESP21154', 'ESP21154', 'VEG', 'VEGETATION', 'ESP01', 'Arbre', 'ESP151', 'Arbre de voirie', 'ESP1018', 'R Jacquard Kenedy à Louvois', '4', 'AR21154', 'Sophora', 'japonica', '', 'Arbre adulte', '', 'MODIF', '1989', '', '', '', '', '', '', '', '', '', '', 'Grenoble Alpes Métropole', '{"type":"Point","coordinates":[5.71902642905011,45.1756135256401]}'], ['13521', 'ESP21153', 'ESP21153', 'VEG', 'VEGETATION', 'ESP01', 'Arbre', 'ESP151', 'Arbre de voirie', 'ESP1018', 'R Jacquard Kenedy à Louvois', '4', 'AR21153', 'Sophora', 'japonica', '', 'Arbre adulte', '', 'MODIF', '1989', '', '', '', '', '', '', '', '', '', '', 'Grenob
# ...

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    naissance = []
    for row in list_annee[1:]:
        if int(row) >= 1989:
            naissance.append(row)
    nombre_arbre = 0
    for row in naissance:
        nombre_arbre += 1
    print(nombre_arbre)
# Out:
# 13350

# %%
# import csv

# with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
#     line_reader = csv.reader(csvfile)
#     Maire_Martin = []
#     Maire_Michallon = []
#     Maire_Dubedout = []
#     Maire_Carignon = []
#     Maire_Destot = []
#     Maire_Piolle = []
#     ref = 0
#     for row in list_annee[1:]:
#         if int(row)>=1950 and int(row)<1959:
#             Maire_Martin.append(row)
#         elif int(row)>=1959 and int(row)<1965:
#             Maire_Michallon.append(row)
#         elif int(row)>=1965 and int(row)<1983:
#             Maire_Dubedout.append(row)
#         elif int(row)>=1983 and int(row)<1995:
#             Maire_Carignon.append(row)
#         elif int(row)>=1995 and int(row)<2014:
#             Maire_Destot.append(row)
#         else:
#             Maire_Piolle.append(row)

# %%
import csv
import matplotlib.pyplot as plt

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    list_annee.pop(-1)
    list_annee.sort()
    
    anneeEnCours = 0
    listePointX = []
    listePointY = []
    counter = 0
    
    for i, row in enumerate(list_annee):
        counter += 1
        if  int(row) != anneeEnCours and anneeEnCours != 0:
            listePointX.append(counter - 1)
            counter = 1
            anneeEnCours = int(row)
            listePointY.append(row)
        if i == len(list_annee) - 1:
            listePointX.append(counter - 1)
        if anneeEnCours == 0:
            listePointY.append(row)
            anneeEnCours = int(row)
plt.bar(listePointY, listePointX)
plt.xlabel("Années", fontsize = 50)
plt.ylabel("Nombre d'arbres", fontsize = 50)
plt.title("Nombre d'arbres en fonction de l'année", fontsize = 50)
plt.gcf().set_size_inches(50, 30)
plt.xticks(fontsize=40, rotation=90)
plt.yticks(fontsize=40)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500., 4000.]),
#  <a list of 9 Text yticklabel objects>)

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    genre_botanique = ()
    list_genre = []
    for row in list_tot:
        genre_botanique = (row[13], row[19])        
        list_genre.append(genre_botanique)
    print(list_genre)
# Out:
# [('GENRE_BOTA', 'ANNEEDEPLANTATION'), ('Acer', '2001'), ('Acer', '2001'), ('Acer', '2001'), ('Acer', '2001'), ('Acer', '2001'), ('Quercus', '2001'), ('Quercus', '2001'), ('Acer', '1975'), ('Salix', '1975'), ('Robinia', '1975'), ('Fraxinus', '2001'), ('Fraxinus', '2001'), ('Robinia', '1975'), ('Acer', '1975'), ('Acer', '1975'), ('Robinia', '1975'), ('Fraxinus', '2001'), ('Robinia', '1975'), ('Prunus', '2001'), ('Acer', '1975'), ('Fraxinus', '2001'), ('Acer', '1975'), ('Acer', '1969'), ('Acer', '1969'), ('Acer', '1969'), ('Acer', '1969'), ('Acer', '1969'), ('Acer', '1969'), ('Acer', '1969'), ('Acer', '1969'), ('Acer', '1969'), ('Acer', '1969'), ('Platanus', '1965'), ('Platanus', '1965'), ('Platanus', '1965'), ('Platanus', '1965'), ('Platanus', '1965'), ('Platanus', '1965'), ('Platanus', '1965'), ('Platanus', '1965'), ('Platanus', '1965'), ('Platanus', '1965'), ('Liriodendron', '2003'), ('Liriodendron', '2003'), ('Liriodendron', '2003'), ('Pinus', '1985'), ('Acer', '1985'), ('Pinus', '1
# ...

# %%
import csv

with open("/home/campus-3/Desktop/Projet_arbre/Data/arbres.csv") as csvfile:
    line_reader = csv.reader(csvfile)
    countGenre = 0
    for row in list_tot:
        if row[13] == "":
            countGenre = countGenre + 1
    print(countGenre)
# Out:
# 1064

# %%
from operator import itemgetter, attrgetter
list_genre = sorted(list_genre, key=itemgetter(1), reverse = True)
print(list_genre)
# Out:
# [('GENRE_BOTA', 'ANNEEDEPLANTATION'), ('Alnus', '2018'), ('Acer', '2018'), ('Acer', '2018'), ('Acer', '2018'), ('Chionanthus', '2018'), ('Chionanthus', '2018'), ('Chionanthus', '2018'), ('Acer', '2018'), ('Liquidambar', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Salix', '2018'), ('Ligustrum', '2018'), ('Ligustrum', '2018'), ('Ligustrum', '2018'), ('Prunus', '2018'), ('Prunus', '2018'), ('Prunus', '2018'), ('Prunus', '2018'), ('Acer', '2018'), ('Acer', '2018'), ('Prunus', '2018'), ('Malus', '2018'), ('Prunus', '2018'), ('Prunus', '2018'), ('Catalpa', '2018'), ('Catalpa', '2018'), ('Acer', '2018'), ('Acer', '2018'), ('Acer', '2018'), ('Paulownia', '2018'), ('Paulownia', '2018'), ('Paulownia', '2018'), ('Chionanthus', '2018'), ('Chionanthus', '2018'), ('Chionanthus', '2018'), ('Chionanthus', '2018'), ('Prunus', '2018'), ('Prunus', '2018'), ('Acer', '
# ...
